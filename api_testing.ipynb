# %% [markdown]
# # Document Experiments

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown
# %load_ext autoreload
# %autoreload 2
from todoist_api_python.api import TodoistAPI
import datetime
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
load_dotenv()
# Out:
# True

# %%
today = datetime.datetime.now()
yesterday = today - datetime.timedelta(days=1)

# %%
api = TodoistAPI(os.getenv("TODOIST_API_KEY"))

# %%
task_list = api.get_completed_tasks_by_completion_date(since=yesterday, until=today)

# %%
for tl in task_list:
    for t in tl:
        print(t)
# Out:
# Task(id='6cgFgH3PJmfcMrGC',
#      content='[How I Turn Any GitHub Repo Into Perfect AI Context '
#              '(Game '
#              'Changer)](https://medium.com/vibe-coding/how-i-turn-any-github-repo-into-perfect-ai-context-game-changer-71919d497531)',
#      description='',
#      project_id='6cgFgCgcFrR8wrqC',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 23),
#              string='23. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=2,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 14, 57, 6, 21600, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 8, 18, 7, 59, 39, 416245, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 14, 57, 6, 674225, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f6rqPXh7Mv23hmp',
#      content='Cheltenham zahlen',
#      description='',
#      project_id='6CrfF3pM9FgFRP7G',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 22),
#              string='22. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=3528,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 14, 51, 49, 631000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 19, 16, 6, 4, 60233, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 14, 51, 50, 264185, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6cffWr678chhP78w',
#      content='[How Instacart Built a Modern Search Infrastructure on '
#              'Postgres](https://tech.instacart.com/how-instacart-built-a-modern-search-infrastructure-on-postgres-c528fa601d54)',
#      description='',
#      project_id='6Vfrcc3V6xpJc62w',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 22),
#              string='22. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=28,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 14, 50, 8, 51700, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 8, 15, 15, 35, 46, 26797, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 14, 50, 9, 744, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6cffHW7QrRxX7FJH',
#      content='[ANTI berlin](https://www.antispaces.com/)',
#      description='',
#      project_id='6VF89cJRq4RrXr5H',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=None,
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=21,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 14, 47, 45, 46900, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 8, 15, 14, 51, 52, 135969, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 14, 47, 46, 20362, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f6pc2HXxWwrQPCG',
#      content='Führung Bundeskanzler Amt',
#      description='',
#      project_id='6CrfF3pM9FgFRP7G',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 22),
#              string='22. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=30,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 14, 46, 56, 3400, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 19, 8, 57, 3, 188196, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 14, 46, 56, 788795, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f43MXW9GM6qVVQC',
#      content='[16 Claude Coding Traps (and the claude.md That Fixes '
#              'Them)](https://generativeai.pub/16-claude-coding-traps-and-the-claude-md-that-fixes-them-e6c344ddf4a4)',
#      description='',
#      project_id='6cgFgCgcFrR8wrqC',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 22),
#              string='22. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=13,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 14, 45, 21, 85100, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 7, 11, 16, 57, 56956, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 14, 45, 22, 235836, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f3XQhM65Fx9rx9p',
#      content='Decke bestellen',
#      description='[Gesteppte Tagesdecke Nivia aus Baumwolle | '
#                  'Westwing](https://www.westwing.de/gesteppte-tagesdecke-nivia-aus-baumwolle-163135.html?simple=DEQ24WES02296-210545)\n'
#                  '\n'
#                  '[Baumwoll-Tagesdecke Ebony | '
#                  'Westwing](https://www.westwing.de/baumwolldecke-ebony-mit-rillen-150246.html?simple=DEQ23WES66458-207602)\n'
#                  '\n'
#                  '[Waffelpiqué-Tagesdecke Allie | '
#                  'Westwing](https://www.westwing.de/waffelpique-tagesdecke-allie-149846.html?simple=DEQ23WES52182-208079)\n'
#                  '\n'
#                  '[Jacquard-Tagesdecke Milano mit grafischem Muster '
#                  '| '
#                  'Westwing](https://www.westwing.de/jacquard-tagesdecke-milano-mit-grafischem-muster-149971.html?simple=DEQ23WES47644-191736&utm_source=google&utm_medium=sea-conversion-nbr&utm_campaign=de_performancemax_nbr_adf&utm_content=20220723054.6468791286.pla&gad_source=1&gad_campaignid=20220725919&gbraid=0AAAAADZC_7-u8JFO_TrgZM0OYel7n_7xb&gclid=Cj0KCQjwrojHBhDdARIsAJdEJ_ePvCn-j7pW9rfGGsGB6Q1ZU_QrUTOMtvGJohBM1KX6c556CZoMCEIaAqhmEALw_wcB)\n'
#                  '\n'
#                  '[Waffelpiqué-Tagesdecke Allie | '
#                  'Westwing](https://www.westwing.de/waffelpique-tagesdecke-allie-149846.html?simple=DEQ23WES52182-208080&utm_source=google&utm_medium=sea-conversion-nbr&utm_campaign=de_performancemax_nbr_adf&utm_content=20220723054.6468791286.pla&gad_source=1&gad_campaignid=20220725919&gbraid=0AAAAADZC_7-u8JFO_TrgZM0OYel7n_7xb&gclid=Cj0KCQjwrojHBhDdARIsAJdEJ_cTfid1LXKK-2O3AEgU_62l8IXXWUbEW3FUaEd0F5OQgjzf94JDtOIaAo08EALw_wcB)',
#      project_id='6Jx2RjXXgRwr55vH',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=1,
#      due=Due(date=datetime.date(2025, 10, 17),
#              string='17. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=287,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 13, 36, 54, 21300, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 5, 14, 39, 32, 160630, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 13, 36, 54, 674330, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f74P2Wp73rxmG6G',
#      content='Richard',
#      description='',
#      project_id='6c48fr5V2cq3wHRc',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 21),
#              string='21. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=3515,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 13, 31, 20, 48400, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 20, 9, 58, 18, 680439, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 13, 31, 21, 74480, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f76JVv6rfx74qH6',
#      content='Linkedin Texte finalisieren',
#      description='',
#      project_id='6c48fr5V2cq3wHRc',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 21),
#              string='Okt 21.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=3517,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 12, 12, 53, 56000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 20, 16, 13, 51, 630421, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 12, 12, 54, 92283, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f3jWCC79gcFpGVj',
#      content='[16 Claude Coding Traps (and the claude.md That Fixes '
#              'Them)](https://generativeai.pub/16-claude-coding-traps-and-the-claude-md-that-fixes-them-e6c344ddf4a4)',
#      description='',
#      project_id='6cgFgCgcFrR8wrqC',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=3,
#      due=Due(date=datetime.date(2025, 10, 20),
#              string='Okt 20.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=9,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 11, 47, 0, 73200, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 6, 6, 55, 29, 10523, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 11, 47, 1, 485365, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f4FH7fJf7jcH3wx',
#      content='[12 Python Tricks That Make My Code '
#              'Self-Documenting](https://medium.com/codrift/12-python-tricks-that-make-my-code-self-documenting-878d075f1e95)',
#      description='',
#      project_id='6X5jx378xQXPr6Xx',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=1,
#      due=Due(date=datetime.date(2025, 10, 20),
#              string='Okt 20.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=81,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 11, 46, 6, 57400, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 8, 12, 39, 34, 650206, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 11, 46, 7, 23871, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6WXrGvW87HFmrC9w',
#      content='[MLOps Fundamentals: A Beginner’s Guide to Docker '
#              'Containerization](https://code.likeagirl.io/mlops-fundamentals-a-beginners-guide-to-docker-containerization-4f5a984e7117)',
#      description='',
#      project_id='6cR24fcvhGhhWp8J',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 20),
#              string='Okt 20.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=12,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 11, 43, 44, 35900, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2024, 11, 7, 17, 24, 42, 868462, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 11, 43, 44, 817601, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f5vcrGvh92RG38G',
#      content='Context7',
#      description='',
#      project_id='6c48fr5V2cq3wHRc',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=1,
#      due=None,
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=3511,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 11, 25, 59, 386000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 15, 12, 9, 51, 795604, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 11, 25, 59, 689621, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
# Task(id='6f76jCW3RMV2Cq76',
#      content='Subfolders UI',
#      description='',
#      project_id='6c48fr5V2cq3wHRc',
#      section_id=None,
#      parent_id=None,
#      labels=[],
#      priority=4,
#      due=Due(date=datetime.date(2025, 10, 21),
#              string='21. Okt.',
#              lang='de',
#              is_recurring=False,
#              timezone=None),
#      deadline=None,
#      duration=None,
#      is_collapsed=False,
#      order=13,
#      assignee_id=None,
#      assigner_id=None,
#      completed_at=datetime.datetime(2025, 10, 21, 9, 56, 34, 422000, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      creator_id='16459379',
#      created_at=datetime.datetime(2025, 10, 20, 17, 24, 9, 717364, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      updated_at=datetime.datetime(2025, 10, 21, 9, 56, 34, 915260, tzinfo=zoneinfo.ZoneInfo(key='UTC')),
#      meta=None)
